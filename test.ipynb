# %%
import pandas as pd

# %%
df=pd.read_csv("./sdrpy/data/sample_data.csv")
df
# Out:
# /tmp/ipykernel_53366/166890509.py:1: DtypeWarning: Columns (17,34,35,38,39,47,54,58,59,86,88,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./sdrpy/data/sample_data.csv")
#                             _id  Dissemination Identifier  \
# 0      65cb4440666de7f4a5284565                 901012687
# 1      65cb4440666de7f4a5284566                 901012688
# 2      65cb4440666de7f4a5284567                 901012689
# 3      65cb4440666de7f4a5284568                 901012690
# 4      65cb4440666de7f4a5284569                 901012691
# ...                         ...                       ...
# 20269  65df7f6fec7ef1f77b95a99f                 916427437
# 20270  65e454fd0a11a96c015c6453                 919835878
# 20271  65e454fd0a11a96c015c6bf7                 918864209
# 20272  65e454fd0a11a96c015c884a                 918763533
# 20273  65e454fd0a11a96c015c8848                 918761897
#
# ...

# %%
from sdrpy.filters.filter_functions import get_trades 
df1 =  get_trades (df, product="xccy", product_type="Basis", currencies="EUR", maturity="m>3", date_range="-3w")
df1
# Out:
# InterestRate:CrossCurrency:Basis
# > 3
#                             _id  Dissemination Identifier  \
# 7680   65cb51db621ad99ae757a0aa                 901180346
# 7681   65cb51db621ad99ae757a0ab                 901180347
# 7685   65cb51df621ad99ae757a0b3                 901180374
# 8343   65cb5595621ad99ae757a627                 901195899
# 8344   65cb5598621ad99ae757a62c                 901196068
# 8909   65cb57ee621ad99ae757aab4                 901217877
# 9505   65cb5b77621ad99ae757b04a                 901232367
# 9863   65cb5d5e621ad99ae757b343                 901235772
# 9864   65cb5d5e621ad99ae757b344                 901235773
# 10411  65cb6875621ad99ae757b7d0                 901243249
# 10412  65cb6875621ad99ae757b7d1                 901243250
# 10419  65cb688a621ad99ae757b7de                 901243260
# 10420  65cb688a621ad99ae757b7df                 901243261
# 10442  65cb694e621ad99ae757b80e                 901243453
# ...

# %%
df1[["Notional amount-Leg 1","USD_notional_leg1","Notional amount-Leg 2","USD_notional_leg2"]]
# Out:
#       Notional amount-Leg 1  USD_notional_leg1 Notional amount-Leg 2  \
# 7680             75,000,000       8.138904e+07            80,737,500
# 7685             26,000,000       2.821487e+07            27,990,300
# 9863             50,116,000       5.438524e+07            54,000,000
# 10411            25,034,750       2.716739e+07            27,000,000
# 10419           101,994,000       1.106826e+08           110,000,000
# 10487            84,336,992       9.152142e+07            91,000,000
# 10631            50,069,500       5.433478e+07            54,000,000
# 10641            25,034,750       2.716739e+07            27,000,000
# 10645            25,034,750       2.716739e+07            27,000,000
# 10652            25,034,750       2.716739e+07            27,000,000
# 13189           215,850,000       2.342377e+08          240,000,000+
# 14438             2,000,000       2.170374e+06             2,142,740
# 15777            10,000,000       1.085187e+07            10,720,000
# ...
