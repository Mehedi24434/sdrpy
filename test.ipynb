# %%
import pandas as pd

# %%
df=pd.read_csv("./sdrpy/data/sample_data.csv")
df
# Out:
# /tmp/ipykernel_152571/166890509.py:1: DtypeWarning: Columns (17,34,35,38,39,47,54,58,59,86,88,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./sdrpy/data/sample_data.csv")
#                             _id  Dissemination Identifier  \
# 0      65cb4440666de7f4a5284565                 901012687
# 1      65cb4440666de7f4a5284566                 901012688
# 2      65cb4440666de7f4a5284567                 901012689
# 3      65cb4440666de7f4a5284568                 901012690
# 4      65cb4440666de7f4a5284569                 901012691
# ...                         ...                       ...
# 20269  65df7f6fec7ef1f77b95a99f                 916427437
# 20270  65e454fd0a11a96c015c6453                 919835878
# 20271  65e454fd0a11a96c015c6bf7                 918864209
# 20272  65e454fd0a11a96c015c884a                 918763533
# 20273  65e454fd0a11a96c015c8848                 918761897
#
# ...

# %%
from sdrpy.filters.filter_functions import get_trades 
df1 =  get_trades (df, product="xccy", product_type="Basis", currencies="CAD", maturity="m>3", date_range="-3w",dv01_min=0.07)
df1
# Out:
# InterestRate:CrossCurrency:Basis
# > 3
#                             _id  Dissemination Identifier  \
# 10074  65cb61f0621ad99ae757b50f                 901240847
# 10090  65cb627f621ad99ae757b530                 901240983
# 10125  65cb634f621ad99ae757b57a                 901241315
# 10157  65cb641c621ad99ae757b5ba                 901241573
#
#        Original Dissemination Identifier Action type Event type  \
# 10074                                NaN        NEWT       TRAD
# 10090                                NaN        NEWT       TRAD
# 10125                                NaN        NEWT       TRAD
# 10157                                NaN        NEWT       TRAD
#
#             Event timestamp Amendment indicator Asset Class  \
# 10074  2024-02-13T12:34:41Z                 NaN          IR
# 10090  2024-02-13T12:37:05Z                 NaN          IR
# 10125  2024-02-13T12:40:26Z                 NaN          IR
# 10157  2024-02-13T12:43:57Z                 NaN          IR
#
# ...

# %%
min_dv01 = 0.1
df1=df1[df1["dv01"]<=min_dv01]
df1
# Out:
#                             _id  Dissemination Identifier  \
# 10090  65cb627f621ad99ae757b530                 901240983
# 10125  65cb634f621ad99ae757b57a                 901241315
# 10157  65cb641c621ad99ae757b5ba                 901241573
#
#        Original Dissemination Identifier Action type Event type  \
# 10090                                NaN        NEWT       TRAD
# 10125                                NaN        NEWT       TRAD
# 10157                                NaN        NEWT       TRAD
#
#             Event timestamp Amendment indicator Asset Class  \
# 10090  2024-02-13T12:37:05Z                 NaN          IR
# 10125  2024-02-13T12:40:26Z                 NaN          IR
# 10157  2024-02-13T12:43:57Z                 NaN          IR
#
#                            Product name Cleared  ...  \
# 10090  InterestRate:CrossCurrency:Basis       N  ...
# 10125  InterestRate:CrossCurrency:Basis       N  ...
# 10157  InterestRate:CrossCurrency:Basis       N  ...
#
# ...
