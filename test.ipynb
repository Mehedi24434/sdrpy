# %%
import pandas as pd

# %%
df=pd.read_csv("./sdrpy/data/sample_data.csv")
df
# Out:
# /tmp/ipykernel_136440/166890509.py:1: DtypeWarning: Columns (17,34,35,38,39,47,54,58,59,86,88,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./sdrpy/data/sample_data.csv")
#                             _id  Dissemination Identifier  \
# 0      65cb4440666de7f4a5284565                 901012687
# 1      65cb4440666de7f4a5284566                 901012688
# 2      65cb4440666de7f4a5284567                 901012689
# 3      65cb4440666de7f4a5284568                 901012690
# 4      65cb4440666de7f4a5284569                 901012691
# ...                         ...                       ...
# 20269  65df7f6fec7ef1f77b95a99f                 916427437
# 20270  65e454fd0a11a96c015c6453                 919835878
# 20271  65e454fd0a11a96c015c6bf7                 918864209
# 20272  65e454fd0a11a96c015c884a                 918763533
# 20273  65e454fd0a11a96c015c8848                 918761897
#
# ...

# %%
from sdrpy.data.data_module import get_data
df=get_data(product="xccy",product_type="FixedFloat",date_range="-15d")
df
# Out:
#                           _id  Dissemination Identifier  \
# 0    65d407ab621ad99ae7599b0a                 905460803
# 1    65d40b1a621ad99ae7599b50                 905461431
# 2    65d40d17621ad99ae7599d5c                 905461975
# 3    65d412e7621ad99ae7599e6e                 905462795
# 4    65d41832621ad99ae7599f07                 905464063
# ..                        ...                       ...
# 460  65e84593b89da9a8f17716f6                 923999614
# 461  65e8464bb89da9a8f1771761                 924008022
# 462  65e84bccb89da9a8f1771a03                 924027852
# 463  65e853f5b89da9a8f1771da4                 924039828
# 464  65e856ffb89da9a8f1771f83                 924043850
#
#      Original Dissemination Identifier Action type Event type  \
# 0                                  NaN        NEWT       TRAD
# 1                                  NaN        NEWT       TRAD
# 2                          905460803.0        CORR        NaN
# ...

# %%
from sdrpy.filters.filter_functions import get_trades 
df1 =  get_trades (df,product="xccy",product_type="FixedFloat",date_range="-3d")
df1
# Out:
# InterestRate:CrossCurrency:FixedFloat
# > 3
#                           _id  Dissemination Identifier  \
# 306  65e58da1b89da9a8f175ba3f                 920759617
# 309  65e58da1b89da9a8f175ba3e                 920759600
# 314  65e58dc5b89da9a8f175ba5e                 920764562
# 315  65e58dc5b89da9a8f175ba5f                 920764588
# 320  65e58ddeb89da9a8f175ba73                 920767768
# 321  65e58ddeb89da9a8f175ba74                 920767775
# 326  65e58df3b89da9a8f175ba85                 920770247
# 327  65e58df3b89da9a8f175ba84                 920770246
# 334  65e5920bb89da9a8f175bca1                 920830614
# 336  65e5920bb89da9a8f175bca4                 920830617
# 338  65e5920bb89da9a8f175bca2                 920830615
# 341  65e5920bb89da9a8f175bca7                 920830620
# 345  65e59fddb89da9a8f175c2f6                 920922287
# 350  65e5ccc3b89da9a8f175d524                 920998938
# 351  65e5cd09b89da9a8f175d54e                 920999003
# ...

# %%
df1["Notional currency-Leg 1"]
# Out:
# 4236    CAD
# 6345    CAD
# 6346    CAD
# 6347    CAD
# 6348    CAD
# 6349    CAD
# 6360    CAD
# 6371    CAD
# 6379    CAD
# 6380    CAD
# 6391    CAD
# 6392    CAD
# 6393    CAD
# 6394    CAD
# Name: Notional currency-Leg 1, dtype: object

# %%
from sdrpy.filters.filter_functions import plot_notional_comparison
plot_notional_comparison(df1,"CLP")

# %%
from sdrpy.data.data_module import get_data
df=get_data()
# Out:
# 2024-02-22 2024-03-06

# %%
df
# Out:
#                            _id  Dissemination Identifier  \
# 0     65d69808621ad99ae75aeb5f                 908943802
# 1     65d69808621ad99ae75aeb60                 908943807
# 2     65d69905621ad99ae75aeb70                 908943934
# 3     65d69905621ad99ae75aeb71                 908943935
# 4     65d69a84621ad99ae75aeba8                 908944222
# ...                        ...                       ...
# 3222  65e83212b89da9a8f1770d50                 923832878
# 3223  65e8327bb89da9a8f1770d87                 923841865
# 3224  65e83293b89da9a8f1770d93                 923844339
# 3225  65e83293b89da9a8f1770d92                 923844330
# 3226  65e83322b89da9a8f1770de4                 923853050
#
#       Original Dissemination Identifier Action type Event type  \
# 0                                   NaN        NEWT       TRAD
# 1                           908943802.0        MODI       TRAD
# 2                                   NaN        NEWT       TRAD
# ...
