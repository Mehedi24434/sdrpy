# %%
import pandas as pd

# %%
df=pd.read_csv("./sdrpy/data/sample_data.csv")
df
# Out:
# /tmp/ipykernel_136440/166890509.py:1: DtypeWarning: Columns (17,34,35,38,39,47,54,58,59,86,88,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./sdrpy/data/sample_data.csv")
#                             _id  Dissemination Identifier  \
# 0      65cb4440666de7f4a5284565                 901012687
# 1      65cb4440666de7f4a5284566                 901012688
# 2      65cb4440666de7f4a5284567                 901012689
# 3      65cb4440666de7f4a5284568                 901012690
# 4      65cb4440666de7f4a5284569                 901012691
# ...                         ...                       ...
# 20269  65df7f6fec7ef1f77b95a99f                 916427437
# 20270  65e454fd0a11a96c015c6453                 919835878
# 20271  65e454fd0a11a96c015c6bf7                 918864209
# 20272  65e454fd0a11a96c015c884a                 918763533
# 20273  65e454fd0a11a96c015c8848                 918761897
#
#        Original Dissemination Identifier Action type Event type  \
# 0                                    NaN        NEWT       COMP
# 1                                    NaN        NEWT       COMP
# 2                                    NaN        NEWT       COMP
# 3                                    NaN        NEWT       COMP
# 4                                    NaN        NEWT       COMP
# ...                                  ...         ...        ...
# 20269                        901863142.0        MODI       TRAD
# 20270                        901246265.0        CORR        NaN
# 20271                        901246265.0        MODI       TRAD
# 20272                        900985241.0        CORR        NaN
# 20273                        900985241.0        TERM       NOVA
#
#             Event timestamp Amendment indicator Asset Class  \
# 0      2024-02-13T06:05:10Z                 NaN          IR
# 1      2024-02-13T06:05:11Z                 NaN          IR
# 2      2024-02-13T06:05:10Z                 NaN          IR
# 3      2024-02-13T06:05:11Z                 NaN          IR
# 4      2024-02-13T06:05:12Z                 NaN          IR
# ...                     ...                 ...         ...
# 20269  2024-02-28T18:45:40Z               False          IR
# 20270  2024-03-01T21:49:05Z                 NaN          IR
# 20271  2024-03-01T08:25:14Z               False          IR
# 20272  2024-03-01T07:24:16Z                 NaN          IR
# 20273  2024-03-01T07:24:16Z                 NaN          IR
#
#                            Product name Cleared  ... Notional amount-Leg 2 mm  \
# 0                                OTHERS       I  ...                      NaN
# 1                                OTHERS       I  ...                      NaN
# 2                                OTHERS       I  ...                      NaN
# 3                                OTHERS       I  ...                      NaN
# 4                                OTHERS       I  ...                      NaN
# ...                                 ...     ...  ...                      ...
# 20269                            OTHERS       N  ...                      NaN
# 20270  InterestRate:CrossCurrency:Basis       N  ...                    260.0
# 20271  InterestRate:CrossCurrency:Basis       N  ...                    260.0
# 20272    InterestRate:IRSwap:FixedFloat       N  ...                     90.0
# 20273    InterestRate:IRSwap:FixedFloat       N  ...                     90.0
#
#                         CreatedAt  \
# 0      2024-02-13 10:28:16.286560
# 1      2024-02-13 10:28:16.286560
# 2      2024-02-13 10:28:16.286560
# 3      2024-02-13 10:28:16.286560
# 4      2024-02-13 10:28:16.286560
# ...                           ...
# 20269  2024-02-28 18:46:07.000864
# 20270  2024-03-03 10:46:16.793114
# 20271  2024-03-03 10:46:16.793114
# 20272  2024-03-03 10:46:16.793114
# 20273  2024-03-03 10:46:16.793114
#
#                                                      URL Product type  \
# 0      https://pddata.dtcc.com/ppd/api/report/intrada...          NaN
# 1      https://pddata.dtcc.com/ppd/api/report/intrada...          NaN
# 2      https://pddata.dtcc.com/ppd/api/report/intrada...          NaN
# 3      https://pddata.dtcc.com/ppd/api/report/intrada...          NaN
# 4      https://pddata.dtcc.com/ppd/api/report/intrada...          NaN
# ...                                                  ...          ...
# 20269  https://pddata.dtcc.com/ppd/api/report/intrada...       OTHERS
# 20270  https://pddata.dtcc.com/ppd/api/report/cumulat...         XCCY
# 20271  https://pddata.dtcc.com/ppd/api/report/cumulat...         XCCY
# 20272  https://pddata.dtcc.com/ppd/api/report/cumulat...      Vanilla
# 20273  https://pddata.dtcc.com/ppd/api/report/cumulat...      Vanilla
#
#                Product sub type Tenor        Date      Time    dv01  \
# 0      NA/Fwd Pr Int Rt Idx EUR     1  2024-02-13  06:05:10  0.0018
# 1      NA/Fwd Pr Int Rt Idx EUR     0  2024-02-13  06:05:11  0.0016
# 2      NA/Fwd Pr Int Rt Idx EUR     0  2024-02-13  06:05:10  0.0011
# 3      NA/Fwd Pr Int Rt Idx EUR     0  2024-02-13  06:05:11  0.0188
# 4      NA/Fwd Pr Int Rt Idx EUR     0  2024-02-13  06:05:12  0.0073
# ...                         ...   ...         ...       ...     ...
# 20269            NA/O P Epn USD     6  2024-02-13  20:11:00     NaN
# 20270                    FltFlt     1  2024-02-13  13:30:59     NaN
# 20271                    FltFlt     1  2024-02-13  13:30:59     NaN
# 20272                    FxdFlt     5  2024-02-13  02:58:30     NaN
# 20273                    FxdFlt     5  2024-02-13  02:58:30     NaN
#
#                      UpdatedAt
# 0      2024-03-04 00:00:50.969
# 1      2024-03-04 00:00:50.969
# 2      2024-03-04 00:00:50.969
# 3      2024-03-04 00:00:50.969
# 4      2024-03-04 00:00:50.969
# ...                        ...
# 20269                      NaN
# 20270                      NaN
# 20271                      NaN
# 20272                      NaN
# 20273                      NaN
#
# [20274 rows x 122 columns]

# %%
from sdrpy.filters.filter_functions import get_trades 
df1 =  get_trades (df, product="xccy", product_type="FixedFloat",date_range="-30d")
df1
# Out:
# InterestRate:CrossCurrency:FixedFloat
# > 3
# /home/mehedi/Documents/sdrpy/sdrpy/utils/util_functions.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Effective Date"] = pd.to_datetime(df["Effective Date"])
# /home/mehedi/Documents/sdrpy/sdrpy/utils/util_functions.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Expiration Date"] = pd.to_datetime(df["Expiration Date"])
# /home/mehedi/Documents/sdrpy/sdrpy/utils/util_functions.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["maturity"] = (df["Expiration Date"] - df["Effective Date"]).dt.days / 365
#                             _id  Dissemination Identifier  \
# 859    65cb486d621ad99ae757681f                 900984624
# 7240   65cb4ee4621ad99ae7579ce1                 901104953
# 7271   65cb4f03621ad99ae7579d1e                 901113599
# 15669  65cb9a81621ad99ae757e31f                 901288520
# 16895  65cba3bd621ad99ae757eceb                 901382206
# 16909  65cba3fc621ad99ae757ed08                 901384771
# 17001  65cba51e621ad99ae757edc7                 901398415
# 17032  65cba5a6621ad99ae757ee18                 901401914
# 17045  65cba5ee621ad99ae757ee31                 901403884
# 18034  65cbb9d8621ad99ae757f679                 901535005
# 18041  65cbba2c621ad99ae757f688                 901535585
# 18042  65cbba2c621ad99ae757f689                 901535591
# 18068  65cbbaf1621ad99ae757f6bd                 901537443
# 18385  65cbc22c621ad99ae757f954                 901552743
#
#        Original Dissemination Identifier Action type Event type  \
# 859                                  NaN        NEWT       TRAD
# 7240                                 NaN        NEWT       TRAD
# 7271                                 NaN        NEWT       TRAD
# 15669                                NaN        NEWT       TRAD
# 16895                                NaN        NEWT       TRAD
# 16909                                NaN        NEWT       TRAD
# 17001                                NaN        NEWT       TRAD
# 17032                                NaN        NEWT       TRAD
# 17045                                NaN        NEWT       TRAD
# 18034                                NaN        NEWT       TRAD
# 18041                        901403884.0        MODI       TRAD
# 18042                                NaN        NEWT       TRAD
# 18068                        901398415.0        MODI       TRAD
# 18385                                NaN        NEWT       TRAD
#
#             Event timestamp Amendment indicator Asset Class  \
# 859    2024-02-13T03:44:04Z                 NaN          IR
# 7240   2024-02-13T07:00:56Z                 NaN          IR
# 7271   2024-02-13T07:08:54Z                 NaN          IR
# 15669  2024-02-13T15:25:24Z                 NaN          IR
# 16895  2024-02-13T17:15:23Z                 NaN          IR
# 16909  2024-02-13T17:16:24Z                 NaN          IR
# 17001  2024-02-13T17:21:21Z                 NaN          IR
# 17032  2024-02-13T17:23:29Z                 NaN          IR
# 17045  2024-02-13T17:24:43Z                 NaN          IR
# 18034  2024-02-13T18:48:59Z                 NaN          IR
# 18041  2024-02-13T17:24:43Z                True          IR
# 18042  2024-02-13T18:48:59Z                 NaN          IR
# 18068  2024-02-13T17:21:21Z                True          IR
# 18385  2024-02-13T19:17:25Z                 NaN          IR
#
#                                 Product name Cleared  ... Product sub type  \
# 859    InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 7240   InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 7271   InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 15669  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 16895  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 16909  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 17001  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 17032  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 17045  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 18034  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 18041  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 18042  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 18068  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
# 18385  InterestRate:CrossCurrency:FixedFloat       N  ...           FxdFlt
#
#       Tenor       Date      Time       dv01                UpdatedAt  \
# 859       5 2024-02-13  03:44:04     7.7852  2024-03-04 00:00:51.054
# 7240      5 2024-02-13  07:00:56    15.2923  2024-03-04 00:00:50.961
# 7271      5 2024-02-13  07:08:54  4387.0461  2024-03-04 00:00:50.961
# 15669     4 2024-02-13  15:25:24     0.5704  2024-03-04 00:00:50.818
# 16895     5 2024-02-13  17:15:23  4944.4304  2024-03-04 00:00:50.760
# 16909    10 2024-02-13  17:16:24  5208.8117  2024-03-04 00:00:50.760
# 17001     8 2024-02-13  17:21:21  6246.2751  2024-03-04 00:00:50.758
# 17032     5 2024-02-13  17:23:29  4944.4304  2024-03-04 00:00:50.758
# 17045    10 2024-02-13  17:24:43  5208.8117  2024-03-04 00:00:50.757
# 18034     7 2024-02-13  18:48:59     0.0510  2024-03-04 00:00:50.741
# 18041    10 2024-02-13  17:24:43        NaN                      NaN
# 18042     6 2024-02-13  18:48:59     0.0524  2024-03-04 00:00:50.741
# 18068     8 2024-02-13  17:21:21        NaN                      NaN
# 18385     6 2024-02-13  19:17:25     0.0524  2024-03-04 00:00:50.736
#
#         maturity Day_diff USD_notional_leg1 USD_notional_leg2
# 859     5.005479  21 days      4.999732e+06      4.999100e+06
# 7240    5.005479  21 days      9.820902e+06      9.830200e+06
# 7271    5.005479  21 days      4.987817e+06      5.000000e+06
# 15669   4.002740  21 days      2.405926e+07      2.900000e+07
# 16895   5.005479  21 days      1.067104e+07      1.078485e+07
# 16909  10.008219  21 days      5.594523e+06      5.654154e+06
# 17001   8.010959  21 days      8.391785e+06      8.481269e+06
# 17032   5.005479  21 days      1.067104e+07      1.078485e+07
# 17045  10.008219  21 days      5.594523e+06      5.654154e+06
# 18034   7.005479  21 days      5.122430e+06      5.000000e+06
# 18041  10.008219  21 days      5.594523e+06      5.654154e+06
# 18042   6.005479  21 days      6.146906e+06      6.000000e+06
# 18068   8.010959  21 days      8.391785e+06      8.481269e+06
# 18385   6.005479  21 days      6.146906e+06      6.000000e+06
#
# [14 rows x 126 columns]

# %%
df1["Notional currency-Leg 2"]
# Out:
# 859      USD
# 7240     USD
# 7271     USD
# 15669    USD
# 16895    CLF
# 16909    CLF
# 17001    CLF
# 17032    CLF
# 17045    CLF
# 18034    USD
# 18041    CLF
# 18042    USD
# 18068    CLF
# 18385    USD
# Name: Notional currency-Leg 2, dtype: object

# %%
from sdrpy.filters.filter_functions import plot_notional_comparison
plot_notional_comparison(df1,"CLF")
