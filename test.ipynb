# %%
import pandas as pd

# %%
df=pd.read_csv("./sdrpy/data/sample_data.csv")
df
# Out:
# /tmp/ipykernel_32206/166890509.py:1: DtypeWarning: Columns (17,34,35,38,39,47,54,58,59,86,88,104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./sdrpy/data/sample_data.csv")
#                             _id  Dissemination Identifier  \
# 0      65cb4440666de7f4a5284565                 901012687
# 1      65cb4440666de7f4a5284566                 901012688
# 2      65cb4440666de7f4a5284567                 901012689
# 3      65cb4440666de7f4a5284568                 901012690
# 4      65cb4440666de7f4a5284569                 901012691
# ...                         ...                       ...
# 20451  65de22ae621ad99ae75d3230                 914701909
# 20452  65df11cd621ad99ae75d7b5e                 915928108
# 20453  65df39cd621ad99ae75d8c1b                 916011899
# 20454  65df45a4621ad99ae75d95e0                 916024382
# 20455  65df7f6c621ad99ae75dc452                 916427437
#
# ...

# %%
from sdrpy.filters.filter_functions import get_trades 
df1 = get_trades(df, product="irswap", product_type="FixedFloat", currencies=["USD"])  # For multiple currencies
df1
# Out:
# currency filter returns; 6148
# InterestRate:IRSwap:FixedFloat
# product filter returns; 474
# > 3
#                             _id  Dissemination Identifier  \
# 4308   65cb4bfb621ad99ae757832f                 901001459
# 10203  65cb6532621ad99ae757b62c                 901241772
# 10204  65cb6532621ad99ae757b62d                 901241773
# 10276  65cb6735621ad99ae757b6bf                 901242812
# 10728  65cb6c6c621ad99ae757ba55                 901245037
# ...                         ...                       ...
# 20263  65d71da5621ad99ae75b1319                 909824935
# 20356  65d9e4d1621ad99ae75beeab                 911753568
# 20360  65d9e4d1621ad99ae75beeb4                 911753577
# 20362  65d9e4d1621ad99ae75beeb6                 911753579
# 20453  65df39cd621ad99ae75d8c1b                 916011899
#
#        Original Dissemination Identifier Action type Event type  \
# 4308                                 NaN        NEWT       TRAD
# ...

# %%
df1 = get_trades(df, maturity="3<m<5", product="irswap", product_type="FixedFloat", currencies=["CAD"])  # For multiple currencies
df1
# Out:
# currency filter returns; 368
# InterestRate:IRSwap:FixedFloat
# product filter returns; 19
#                         _id  Dissemination Identifie  \
# 0  65cbd1cb621ad99ae75800f1                901564762
# 1  65cbd54e621ad99ae7580178                901564761
# 2  65cbd54e621ad99ae7580179                901564763
# 3  65cbd54e621ad99ae758017b                901564766
# 4  65cbd54e621ad99ae758017d                901564774
# 5  65ccec91621ad99ae75867e9                902030682
# 6  65ccec91621ad99ae75867ea                902030683
# 7  65ccec91621ad99ae75867eb                902030684
#
#    Original Dissemination Identifie Action type Event type  \
# 0                               NaN        NEWT       TRAD
# 1                               NaN        NEWT       TRAD
# 2                               NaN        NEWT       TRAD
# 3                               NaN        NEWT       TRAD
# 4                               NaN        NEWT       TRAD
# ...

# %%
df1 = get_trades(df, maturity="m<3, m>8", product="irswap", product_type="FixedFloat", currencies=["CAD"])  # For multiple currencies
df1
# Out:
# currency filter returns; 368
# InterestRate:IRSwap:FixedFloat
# product filter returns; 19
#                         _id  Dissemination Identifier  \
# 0  65cb901c621ad99ae757d8bd                 901276672
# 1  65cba591621ad99ae757ee0e                 901401488
# 2  65cba591621ad99ae757ee0f                 901401678
# 3  65cbb449621ad99ae757f4a6                 901517203
# 4  65cbb449621ad99ae757f4a7                 901517204
#
#    Original Dissemination Identifier Action type Event type  \
# 0                                NaN        NEWT       TRAD
# 1                        901276672.0        CORR        NaN
# 2                        901276672.0        TERM       NOVA
# 3                                NaN        NEWT       TRAD
# 4                                NaN        NEWT       TRAD
#
#         Event timestamp Amendment indicator Asset Class  \
# 0  2024-02-13T15:51:40Z                 NaN          IR
# 1  2024-02-13T17:23:14Z                 NaN          IR
# ...
