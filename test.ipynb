# %%
from sdrpy.data.data_module import get_data
df=get_data(product="xccy",product_type="FixedFloat",date_range="-3d")
df
# Out:
#                           _id  Dissemination Identifier  \
# 0    65e52d21b89da9a8f175a750                 919999106
# 1    65e56e2bb89da9a8f175b3ce                 920108398
# 2    65e577acb89da9a8f175b4c2                 920229506
# 3    65e58d97b89da9a8f175ba35                 920757834
# 4    65e58d97b89da9a8f175ba36                 920757853
# ..                        ...                       ...
# 245  65e9851bb89da9a8f177aa46                 925866840
# 246  65e986f1b89da9a8f177ab2e                 925905456
# 247  65e987cdb89da9a8f177abda                 925923929
# 248  65e990cab89da9a8f177b114                 925975496
# 249  65e991fab89da9a8f177b20c                 925981208
#
#      Original Dissemination Identifier Action type Event type  \
# 0                                  NaN        NEWT       TRAD
# 1                                  NaN        NEWT       TRAD
# 2                                  NaN        NEWT       TRAD
# ...

# %%
from sdrpy.filters.filter_functions import get_trades 
df1 =  get_trades (df, product="xccy",product_type="FixedFloat",date_range="-2d",currencies=("USD","PEN","CAD","TRY"))
df1
# Out:
# InterestRate:CrossCurrency:FixedFloat
# > 3
#                           _id  Dissemination Identifier  \
# 71   65e6c558b89da9a8f1766650                 921698148
# 73   65e6ce44b89da9a8f17667d7                 921847712
# 75   65e6d1d9b89da9a8f17668d0                 921831779
# 82   65e6e14bb89da9a8f1767237                 922303775
# 85   65e6eb2db89da9a8f1767963                 922388859
# ..                        ...                       ...
# 242  65e97b49b89da9a8f177a3c1                 925670956
# 243  65e981e0b89da9a8f177a7af                 925829838
# 246  65e986f1b89da9a8f177ab2e                 925905456
# 247  65e987cdb89da9a8f177abda                 925923929
# 248  65e990cab89da9a8f177b114                 925975496
#
#      Original Dissemination Identifier Action type Event type  \
# 71                                 NaN        NEWT       TRAD
# 73                         921698148.0        MODI       TRAD
# ...

# %%
df2= get_trades (df, product="xccy",product_type="FixedFloat",date_range="-3d",currency="INR")
df2
# Out:
# InterestRate:CrossCurrency:FixedFloat
# > 3
#                           _id  Dissemination Identifier  \
# 70   65e69a5ab89da9a8f17625e4                 921541925
# 71   65e6c558b89da9a8f1766650                 921698148
# 73   65e6ce44b89da9a8f17667d7                 921847712
# 101  65e72604b89da9a8f176989e                 922503955
# 233  65e96e8bb89da9a8f1779cda                 925354174
#
#      Original Dissemination Identifier Action type Event type  \
# 70                                 NaN        NEWT       TRAD
# 71                                 NaN        NEWT       TRAD
# 73                         921698148.0        MODI       TRAD
# 101                                NaN        NEWT       TRAD
# 233                                NaN        NEWT       TRAD
#
#           Event timestamp Amendment indicator Asset Class  \
# 70   2024-03-04T07:41:25Z                 NaN          IR
# 71   2024-03-05T07:09:52Z                 NaN          IR
# ...

# %%
from sdrpy.plotting.plot import plot_notional_comparison
plot_notional_comparison(df1,currencies=("USD","PEN","CAD","TRY"))
# Out:
# /home/mehedi/Documents/sdrpy/sdrpy/plotting/plot.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] in dict_data:
# /home/mehedi/Documents/sdrpy/sdrpy/plotting/plot.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dict_data[row[0]] = row[1]
# /home/mehedi/Documents/sdrpy/sdrpy/plotting/plot.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] in dict_data:
# ...

# %%
plot_notional_comparison(df1,currency="TRY")

# %%
from sdrpy.filters.reports import traded_currency
traded_currency(df1)
# Out:
# Currencies used over the past 24 Hours: ['EUR', 'TRY', 'INR', 'AUD', 'PEN', 'CNY', 'USD']
#           Total_Sum in million  No of Contracts     USD Amount
# Currency
# USD              1010777592000               68  1010777592000
# AUD               543033480000                7   355341892422
# EUR               181000000000                8   197060424605
# CNY              1364910000000                9   189468204722
# PEN               522024566000               26   139221401216
# TRY              2585514700000               15    81331069518
# INR              3800000000000                3    45864030048
